# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]   # Time Values
y = [2, 4, 6]   # Position Values

plt.plot(x, y)  # Plot Position vs. Time
plt.title('Position vs. Time')
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.show()
